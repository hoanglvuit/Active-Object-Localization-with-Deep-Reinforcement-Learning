# %%
import os
os.makedirs('models')
os.makedirs('media')
os.makedirs('media2')

# %%
# !git clone https://github.com/AfIlen12/Active_Localization.git
# Out:
# fatal: destination path 'Active_Localization' already exists and is not an empty directory.

# %%
# %run /kaggle/working/Active_Localization/training.ipynb
# Out:
# ...
# 100%|██████████| 1999639040/1999639040 [01:06<00:00, 30100562.65it/s]
# Extracting ./datasets/VOCtrainval_11-May-2012.tar to ./datasets/
# Using downloaded and verified file: ./datasets/VOCtrainval_11-May-2012.tar
# Extracting ./datasets/VOCtrainval_11-May-2012.tar to ./datasets/
# ...
# 100%|██████████| 460032000/460032000 [00:16<00:00, 27959368.69it/s]
# Extracting ./datasets/VOCtrainval_06-Nov-2007.tar to ./datasets/
# Using downloaded and verified file: ./datasets/VOCtrainval_06-Nov-2007.tar
# Extracting ./datasets/VOCtrainval_06-Nov-2007.tar to ./datasets/
#   0%|          | 0/4 [00:00<?, ?it/s]
# Classe cat...
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
# %run /kaggle/working/Active_Localization/visualize.ipynb

# %%
# %run /kaggle/working/Active_Localization/ex.ipynb

# %%
import shutil
from IPython.display import FileLink

# Đường dẫn đến thư mục bạn muốn tải xuống (thường là '/kaggle/working/tên_thư_mục')
folder_path = '/kaggle/working/media'

# Tạo tệp ZIP
shutil.make_archive('media', 'zip', folder_path)

# Tạo liên kết tải xuống
FileLink(r'media.zip')

# %%
import shutil
from IPython.display import FileLink

# Đường dẫn đến thư mục bạn muốn tải xuống (thường là '/kaggle/working/tên_thư_mục')
folder_path = '/kaggle/working/media2'

# Tạo tệp ZIP
shutil.make_archive('media2', 'zip', folder_path)

# Tạo liên kết tải xuống
FileLink(r'media2.zip')
